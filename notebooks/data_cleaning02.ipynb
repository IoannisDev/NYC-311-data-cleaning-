# %%
import pandas as pd
import numpy as np
import scipy as st
import matplotlib.pyplot as plt
import seaborn as sns
import dotenv
import os
dotenv.load_dotenv()
# Out:
# True

# %%
DIR = os.getenv("PROJECT_DIR")
df = pd.read_csv(DIR+"/data/cleaned/cleaned_nyc_311_dataset.csv")

# %%
df.describe()
# Out:
#          unique_key   incident_zip  council_district           bbl  \
# count  1.460640e+05  145348.000000     145348.000000  1.322090e+05
# mean   5.649490e+07   10810.937763         24.865206  2.717488e+09
# std    4.902301e+04     534.537184         14.538487  1.155701e+09
# min    5.640868e+07   10000.000000          1.000000  0.000000e+00
# 25%    5.645405e+07   10451.000000         12.000000  2.027860e+09
# 50%    5.649478e+07   11201.000000         24.000000  3.016520e+09
# 75%    5.653545e+07   11232.000000         37.000000  4.005230e+09
# max    6.074042e+07   11697.000000         51.000000  5.240010e+09
#
#        x_coordinate_state_plane  y_coordinate_state_plane       latitude  \
# count              1.460640e+05             146064.000000  146064.000000
# mean               1.005044e+06             207223.150838      40.735405
# std                2.138475e+04              31995.750796       0.087821
# min                9.140500e+05             121305.000000      40.499379
# 25%                9.930420e+05             183046.000000      40.669061
# 50%                1.004379e+06             205137.500000      40.729659
# 75%                1.017653e+06             237230.250000      40.817780
# max                1.067179e+06             271730.000000      40.912468
#
#            longitude
# count  146064.000000
# mean      -73.924927
# std         0.077124
# min       -74.252452
# 25%       -73.968286
# 50%       -73.927340
# 75%       -73.879266
# max       -73.700736
